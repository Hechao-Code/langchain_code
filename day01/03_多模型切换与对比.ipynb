# %% [markdown]
# ## 1. 接入不同平台的模型调用

# %% [markdown]
# ### 1.1 接入兼容 OpenAI 格式的平台

# %% [markdown]
# #### 1.1.1  通过 CloseAI 代理调用 OpenAI

# %% [markdown]
# #### 1.1.2  直连 DeepSeek

# %% [markdown]
# #### 1.1.3 硅基流动调用开源模型

# %% [markdown]
# ### 1.2  接入不兼容 OpenAI 格式的平台

# %% [markdown]
# ## 2. 调用本地模型
